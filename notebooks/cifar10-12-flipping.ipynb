# %%
import os
os.chdir('../')
from mutil.cometml_plt import grid_plot_experiments
import comet_ml
comet_api = comet_ml.API(api_key="cgss7piePhyFPXRw1J2uUEjkQ", rest_api_key="G9ts5ZxTui6k0ruDTtoQpqCkI")
import holoviews as hv
import warnings
warnings.filterwarnings('ignore')
hv.extension('matplotlib')

import pandas as pd
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %%
experiments = comet_api.get("matech96/cifar10-12-flipping")

# %%
grid_plot_experiments(comet_api, experiments, 'horizontal_flip', 'vertical_flip', parameters=['curr_epoch'], fig_size=100)
# Out:
# :Layout
#    .HeatMap.I   :HeatMap   [horizontal_flip,vertical_flip]   (curr_epoch)
#    .HeatMap.II  :HeatMap   [horizontal_flip,vertical_flip]   (train_acc)
#    .HeatMap.III :HeatMap   [horizontal_flip,vertical_flip]   (dev_acc)
#    .HeatMap.IV  :HeatMap   [horizontal_flip,vertical_flip]   (test_acc)

# %%
import os
os.chdir('../')
from mutil.cometml_plt import grid_plot_experiments
import comet_ml
comet_api = comet_ml.API(api_key="cgss7piePhyFPXRw1J2uUEjkQ", rest_api_key="G9ts5ZxTui6k0ruDTtoQpqCkI")
import holoviews as hv
import warnings
warnings.filterwarnings('ignore')
hv.extension('matplotlib')

import pandas as pd
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %%
experiments = comet_api.get("matech96/cifar10-10-initialization")

# %%
list2float = lambda l: float(l[0])
list2int = lambda l: int(l[0])
accs = [list2float(comet_api.get_experiment_metrics(experiment.key, 'train_acc')) for experiment in experiments]
dev_accs = [list2float(comet_api.get_experiment_metrics(experiment.key, 'dev_acc')) for experiment in experiments]
stop_epochs = [list2int(comet_api.get_experiment_parameters(experiment.key, 'curr_epoch')) for experiment in experiments]
initializations = [comet_api.get_experiment_parameters(experiment.key, 'initialization')[0] for experiment in experiments]

# %%
data = {'initialization': initializations, 'dev acc': dev_accs, 'number of epochs': stop_epochs}
(hv.Scatter(data, vdims=['dev acc'], kdims=['number of epochs']) * hv.Labels(data, vdims=['initialization'], kdims=['number of epochs', 'dev acc'])).opts(title='Epochs until convergance by initialization', aspect=2, fig_size=400)
# Out:
# :Overlay
#    .Scatter.I :Scatter   [number of epochs]   (dev acc)
#    .Labels.I  :Labels   [number of epochs,dev acc]   (initialization)

# %%
hv.Bars(pd.DataFrame({'initialization': initializations, 'number of epochs': stop_epochs})).opts(title='Epochs until convergance by initialization', aspect=2, fig_size=400)
# Out:
# :Bars   [initialization]   (number of epochs)

# %%
initializations
# Out:
# [['TruncatedNormal'],
#  ['VarianceScaling'],
#  ['glorot_normal'],
#  ['glorot_uniform'],
#  ['he_normal'],
#  ['he_uniform']]

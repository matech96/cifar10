# %%
import os
os.chdir('../')
from mutil.cometml_plt import grid_plot_experiments
import comet_ml
comet_api = comet_ml.API(api_key="cgss7piePhyFPXRw1J2uUEjkQ", rest_api_key="G9ts5ZxTui6k0ruDTtoQpqCkI")
import holoviews as hv
import warnings
warnings.filterwarnings('ignore')
hv.extension('matplotlib')

import pandas as pd
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
experiments = comet_api.get("matech96/cifar10-09-initialization")

# %%
list2float = lambda l: float(l[0])
list2int = lambda l: int(l[0])
accs = [list2float(comet_api.get_experiment_metrics(experiment.key, 'train_acc')) for experiment in experiments]
dev_accs = [list2float(comet_api.get_experiment_metrics(experiment.key, 'dev_acc')) for experiment in experiments]
stop_epochs = [list2int(comet_api.get_experiment_parameters(experiment.key, 'curr_epoch')) for experiment in experiments]
initializations = [comet_api.get_experiment_parameters(experiment.key, 'initialization')[0] for experiment in experiments]

# %%
data = {'initialization': initializations, 'dev acc': dev_accs, 'number of epochs': stop_epochs}
(hv.Scatter(data, vdims=['dev acc'], kdims=['number of epochs']) * hv.Labels(data, vdims=['initialization'], kdims=['number of epochs', 'dev acc'])).opts(
    hv.opts.Labels(yoffset=0.002, size=14, padding=0.2),
    ).opts(aspect=2, fig_size=400)
# Out:
# :Overlay
#    .Scatter.I :Scatter   [number of epochs]   (dev acc)
#    .Labels.I  :Labels   [number of epochs,dev acc]   (initialization)

# %%
import os
os.chdir('../')
import holoviews as hv
import warnings
warnings.filterwarnings('ignore')
hv.extension('matplotlib')
import pandas as pd
import numpy as np

from mutil import ProjectWrapper
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
from itertools import compress

# %%
experiments = ProjectWrapper("matech96/cifar10-23-lr-schedule")

# %%
names = experiments.get_names()[:-1]

# %%
cyclic_mask = list(map(lambda s: s.startswith('cyclic'), names))
cyclic_names = list(compress(names, cyclic_mask))

# %%
dfs = list(compress(experiments.get_csvs(), cyclic_mask))

# %%
fig = hv.Overlay()
for name, df in zip(cyclic_names, dfs):
    fig *= hv.Curve(df['val_acc'], kdims='epoch', label=name)
fig.opts(aspect=2, fig_size=400)#width=800, height=500)
# Out:
# :Overlay
#    .Curve.Cyclic_linear100              :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_linear200              :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_linear300              :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_linear400              :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_2order_100             :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_2order_200             :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_2order_300             :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_2order_400             :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_0_full_stop_5order_100 :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_0_full_stop_5order_200 :Curve   [epoch]   (val_acc)
#    .Curve.Cyclic_0_full_stop_5order_300 :Curve   [epoch]   (val_acc)

# %%
reset_epochs = [int((df['epoch'].max() + 1) / 4) for df in dfs]

# %%
max_per_cycles = []
fig = hv.Overlay()
for name, reset_epoch, df in zip(cyclic_names, reset_epochs, dfs):
    max_per_cycle = [df['val_acc'][:i*reset_epoch].max() for i in range(1, 5)]
    max_per_cycles.append(max_per_cycle)
    
    fig *= hv.Curve(max_per_cycle, vdims='val_acc', kdims='reset', label=name)
fig.opts(aspect=2, fig_size=400)
# Out:
# :Overlay
#    .Curve.Cyclic_linear100              :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_linear200              :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_linear300              :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_linear400              :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_2order_100             :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_2order_200             :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_2order_300             :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_2order_400             :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_0_full_stop_5order_100 :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_0_full_stop_5order_200 :Curve   [reset]   (val_acc)
#    .Curve.Cyclic_0_full_stop_5order_300 :Curve   [reset]   (val_acc)

# %%
fig = hv.Overlay()
increase_per_cycles = []
for name, max_per_cycle in zip(cyclic_names, max_per_cycles):
    increase_per_cycle = [max_per_cycle[i+1] - max_per_cycle[i] for i in range(len(max_per_cycle)-1)]
    increase_per_cycles.append(increase_per_cycle)
    
    fig *= hv.Curve(increase_per_cycle, vdims='val_acc increase', kdims='reset', label=name)
fig.opts(aspect=2, fig_size=400)
# Out:
# :Overlay
#    .Curve.Cyclic_linear100              :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_linear200              :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_linear300              :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_linear400              :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_2order_100             :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_2order_200             :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_2order_300             :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_2order_400             :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_0_full_stop_5order_100 :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_0_full_stop_5order_200 :Curve   [reset]   (val_acc increase)
#    .Curve.Cyclic_0_full_stop_5order_300 :Curve   [reset]   (val_acc increase)

# %%
data_dfs = []
figs = {}
for reset_id in range(3):
    max_at = [max_per_cycle[reset_id+1] for max_per_cycle in max_per_cycles]
    increase_at = [increase_per_cycle[reset_id] for increase_per_cycle in increase_per_cycles]
    df = pd.DataFrame({'name': cyclic_names, 'max_val_acc': max_at, 'increase': increase_at})
    data_dfs.append(df)
    
    fig = (hv.Scatter(df, vdims=['increase'], kdims=['max_val_acc'])
         * hv.Labels(df, vdims=['name'], kdims=['max_val_acc', 'increase'])
        ).opts(aspect=2, fig_size=400).opts(hv.opts.Labels(yoffset=0.0002, size=10, padding=0.2))
    figs[reset_id] = fig

# %%
imgs_dir = 'notebooks/cifar10-23-lr-schedule'
os.makedirs(imgs_dir, exist_ok=True)
holo_map = hv.HoloMap(figs, kdims='reset number')
hv.save(holo_map, os.path.join(imgs_dir, 'acc_increase.html'))

# %%
hv.extension('matplotlib')
fig = hv.Overlay()
for name, max_per_cycle, increase_per_cycle in zip(cyclic_names, max_per_cycles, increase_per_cycles):
    data = {'val_acc': max_per_cycle[1:], 'increase': increase_per_cycle}
    fig *= hv.Curve(data, kdims='val_acc', vdims='increase', label=name)
fig.opts(aspect=2, fig_size=400)
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# :Overlay
#    .Curve.Cyclic_linear100              :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_linear200              :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_linear300              :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_linear400              :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_2order_100             :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_2order_200             :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_2order_300             :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_2order_400             :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_0_full_stop_5order_100 :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_0_full_stop_5order_200 :Curve   [val_acc]   (increase)
#    .Curve.Cyclic_0_full_stop_5order_300 :Curve   [val_acc]   (increase)
